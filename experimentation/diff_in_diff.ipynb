# %% [markdown]
# #  diff in diff.Value.ToUpper() iff  diff in diff.Value.ToUpper() n  diff in diff.Value.ToUpper() iffCompanion notes: $MdPath",
#                     ",
#                     - Work through the concepts below.- Keep this notebook runnable end-to-end.---

# %%
import numpy as npimport pandas as pdpd.set_option('display.max_columns', 200)

# %%
# TODO: Add a small, synthetic dataset# and demonstrate the core concept
